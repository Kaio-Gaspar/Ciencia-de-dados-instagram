# %%
import pandas as pd
df = pd.read_excel("08. Analisando o engajamento no Instagram.xlsx")

# %%
df = df.drop('Visualizações', axis=1)
df.loc[df.Carrossel.isnull(), 'Carrossel'] = 'N'
df.head(5)
# Out:
#     Tipo       Data  Curtidas  Comentários           Tags Pessoas Campanhas  \
# 0   Foto 2021-09-11      2858           16           Loja       N         N
# 1   Foto 2021-09-11      2930           28  Loja/Produtos       N         N
# 2   Foto 2021-09-11      2807            9           Loja       N         N
# 3  Vídeo 2021-09-12      5115           49       Produtos       N         N
# 4   Foto 2021-09-13      4392           45       Produtos       S         N
#
#   Carrossel  Interacoes
# 0         N         2874
# 1         N         2958
# 2         N         2816
# 3         N         5164
# 4         N         4437

# %%
pd.options.display.float_format = '{:,.2f}'.format
df.groupby('Tags')['Curtidas'].mean()
# Out:
# Tags
# Datas comemorativas                 17,975.00
# Datas comemorativas/Promoções       29,084.00
# Dicas de como usar/Novos Produtos    5,703.50
# Dicas de como usar/Produtos          7,586.67
# Influenciadores                     15,197.29
# Loja                                 2,832.50
# Loja/Produtos                        2,930.00
# Novos Produtos                      11,619.57
# Produtos                             5,666.92
# Promoções                           26,645.50
# Trends                              22,400.67
# Trends/Produtos                     12,894.00
# Name: Curtidas, dtype: float64

# %% [markdown]
# ## Dividir linhas com 2 tags em 2 linhas
# função split

# %%
txt= 'teste função split dividindo  texto'
txt.split()
# Out:
# ['teste', 'função', 'split', 'dividindo', 'texto']

# %%
txt= 'teste-função-split-dividindo-t-e-x-t-o'
txt.split('-')
# Out:
# ['teste', 'função', 'split', 'dividindo', 't', 'e', 'x', 't', 'o']

# %%
df.Tags = df.Tags.str.split('/')
df.head()
# Out:
#     Tipo       Data  Curtidas  Comentários              Tags Pessoas  \
# 0   Foto 2021-09-11      2858           16            [Loja]       N
# 1   Foto 2021-09-11      2930           28  [Loja, Produtos]       N
# 2   Foto 2021-09-11      2807            9            [Loja]       N
# 3  Vídeo 2021-09-12      5115           49        [Produtos]       N
# 4   Foto 2021-09-13      4392           45        [Produtos]       S
#
#   Campanhas Carrossel  Interacoes
# 0         N         N         2874
# 1         N         N         2958
# 2         N         N         2816
# 3         N         N         5164
# 4         N         N         4437

# %% [markdown]
# ## Separa a coluna tags em 1 linha para cada elemento da lista

# %%
df = df.explode('Tags')
df.head()
# Out:
#     Tipo       Data  Curtidas  Comentários      Tags Pessoas Campanhas  \
# 0   Foto 2021-09-11      2858           16      Loja       N         N
# 1   Foto 2021-09-11      2930           28      Loja       N         N
# 1   Foto 2021-09-11      2930           28  Produtos       N         N
# 2   Foto 2021-09-11      2807            9      Loja       N         N
# 3  Vídeo 2021-09-12      5115           49  Produtos       N         N
#
#   Carrossel  Interacoes
# 0         N         2874
# 1         N         2958
# 1         N         2958
# 2         N         2816
# 3         N         5164

# %%
df.groupby('Tags')[['Curtidas', 'Comentários']].mean().sort_values('Curtidas', ascending=False)
# Out:
#                      Curtidas  Comentários
# Tags
# Promoções           27,458.33       531.00
# Datas comemorativas 20,752.25       343.50
# Trends              20,024.00       352.25
# Sem Tags            15,347.88       207.75
# Influenciadores     15,197.29       161.71
# Novos Produtos      10,304.89       198.56
# Dicas de como usar   6,833.40       133.60
# Produtos             6,269.82        94.12
# Loja                 2,865.00        17.67

# %%
df.loc[df.Tags.isnull(), 'Tags'] = 'Sem Tags'
df['Tags']
# Out:
# 0                    Loja
# 1                    Loja
# 1                Produtos
# 2                    Loja
# 3                Produtos
# 4                Produtos
# 5          Novos Produtos
# 6          Novos Produtos
# 7                Produtos
# 8                Produtos
# 9                Produtos
# 10                 Trends
# 10               Produtos
# 11               Sem Tags
# 12         Novos Produtos
# 13              Promoções
# 14    Datas comemorativas
# 15               Produtos
# 16               Produtos
# 17               Produtos
# 18               Produtos
# 19               Sem Tags
# 20               Produtos
# 21               Produtos
# 22        Influenciadores
# 23        Influenciadores
# 24                 Trends
# 25         Novos Produtos
# 26    Datas comemorativas
# 27         Novos Produtos
# 28         Novos Produtos
# 29               Sem Tags
# 30                 Trends
# 31         Novos Produtos
# 32     Dicas de como usar
# ...

# %%
df.groupby(['Pessoas', 'Tags',])[['Curtidas', 'Comentários']].mean().sort_values('Curtidas', ascending=False)
# Out:
#                                        Curtidas  Comentários
# Pessoas Tags                Campanhas
# S       Promoções           S         33,217.50       490.50
#         Trends              S         22,400.67       386.67
#         Datas comemorativas S         20,752.25       343.50
#         Influenciadores     S         18,715.40       197.60
#         Sem Tags            S         16,850.75       257.75
#         Promoções           N         15,940.00       612.00
#         Novos Produtos      S         13,881.50       453.50
#         Sem Tags            N         13,845.00       157.75
#         Trends              N         12,894.00       249.00
#         Produtos            S         11,802.00       102.00
#         Novos Produtos      N          9,937.00       136.33
#         Produtos            N          7,818.43       135.86
#         Dicas de como usar  N          6,833.40       133.60
#         Influenciadores     N          6,402.00        72.00
# ...

# %%
df.groupby(['Campanhas', 'Tags',])[['Curtidas', 'Comentários']].mean().sort_values('Curtidas', ascending=False)
# Out:
#                                Curtidas  Comentários
# Campanhas Tags
# S         Promoções           33,217.50       490.50
#           Trends              22,400.67       386.67
#           Datas comemorativas 20,752.25       343.50
#           Influenciadores     18,715.40       197.60
#           Sem Tags            16,850.75       257.75
# N         Promoções           15,940.00       612.00
#           Sem Tags            13,845.00       157.75
#           Trends              12,894.00       249.00
# S         Novos Produtos      11,040.67       323.00
# N         Novos Produtos       9,937.00       136.33
# S         Produtos             9,074.00        67.50
# N         Dicas de como usar   6,833.40       133.60
#           Influenciadores      6,402.00        72.00
#           Produtos             5,895.93        97.67
#           Loja                 2,865.00        17.67

# %% [markdown]
# ## Conclusões
# Ter rostos de pessoas é fundamental
# campanhas ajudam na divulgação da marca
# promoções possuem o maior engajamento
# trends e datas comemorativas ajudam no engajamento
# nao é possível afirmar que a tag loja é ruim até testar incluindo campanha e pessoas
